# %%
import glob
import pandas as pd
import numpy as np
import requests
import os

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import time
import re
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix
import joblib

# %%
all_file = glob.glob("../Project/Data/*.xlsx")
len(all_file)
# Out:
# 20

# %%
names = []
count = []
clusters = []
data = []

for each in all_file:    
    temp = pd.read_excel(each)
    
    count.append(len(temp))
    names.append(each.split('\\')[1][:-5])
    clusters.append(temp['idx'].iloc[4])
    
    data.append(temp)
    cluster_ids = clusters

# %%
data = pd.concat(data)
data = data.sample(frac = 1)

data
# Out:
#      Unnamed: 0                                            content  idx
# 725       14725  বিলাওয়াল ভুট্টো জারদারি জন্ম সেপ্টেম্বর পাকিস...   15
# 451        9451               গ্রেগরীয় বর্ষপঞ্জীর একটি সাধারণ বছর   10
# 937        2937  কোন গ্রহের জলমণ্ডল বলতে ঐ গ্রহের পৃষ্ঠসংলগ্ন অ...    3
# 2         16002  শ্রীজীব ন্যায়তীর্থ জানুয়ারি অক্টোবর একজন বিশ...   17
# 299       17299  দাওয়াত দা ওয়াহ নামেও পরিচিত আরবি আমন্ত্রণ অর...   18
# ..          ...                                                ...  ...
# 740         740  উচ্চ মধ্যযুগের গোড়ার দিকে যে সময়ে নানাবিধ বি...    1
# 242        9242               গ্রেগরীয় বর্ষপঞ্জীর একটি সাধারণ বছর   10
# 265       14265  নিখিল ভারত মুসলিম লীগ সালে ঢাকায় প্রতিষ্ঠিত ব...   15
# 161       16161  ভারতের উত্তর প্রদেশের রাজ্যের সরকার প্রধান হচ্...   17
# 273       14273  স্যার উইলিয়াম ওয়ালেস la villemus valensis c ...   15
#
# [20000 rows x 3 columns]

# %%
stop_words = [ 'হাই', 'ফ্রিকুয়েন্সি', 'কিন্তু', 'অপ্রয়োজনীয়', 'শব্দ' ]

# %%
data['content'] = data['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))

# %%
X_train, X_test, y_train, y_test = train_test_split(data['content'], data['idx'], test_size=0.33, random_state=42 )

# %%
# Classification report

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn import metrics

total_data_count = len(data)
per_class_counts = []
unique_classes = np.unique(data['idx'].values)
class_count_mean = np.mean(count)


from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([
    
    ('vect', CountVectorizer(stop_words=stop_words,
                            analyzer="word", 
                            lowercase=False,
                            token_pattern="[\S]*",
                            tokenizer=None,
                            ngram_range=(1, 3),
                            preprocessor=None)),                 
    ('tfidf', TfidfTransformer()),
    ('clf-svm', SGDClassifier(loss = 'modified_huber', penalty='l2', max_iter=100)),
                                                                        
])
classifier = text_clf_svm.fit(list(X_train), list(y_train))


cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
score = cross_val_score(text_clf_svm, list(X_train), list(y_train), cv=cv)

print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))


predicted = classifier.predict(X_test)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Cross Accuracy: 0.43 (+/- 0.01)

# %%
joblib.dump(classifier, "../Model/sample_model.pickle")
# Out:
# ['../Model/sample_model.pickle']

# %%
print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print(metrics.classification_report(y_test, predicted))
# Out:
# Cross Accuracy: 0.44 (+/- 0.01)
#               precision    recall  f1-score   support
#
#            1       0.38      0.26      0.31       305
#            2       0.55      0.46      0.50       300
#            3       0.28      0.41      0.33       323
#            4       0.42      0.36      0.38       335
#            5       0.24      0.49      0.32       328
#            6       0.27      0.47      0.34       323
#            7       0.52      0.52      0.52       359
#            8       0.56      0.33      0.42       318
#            9       0.49      0.90      0.64       313
#           10       0.70      0.05      0.10       353
#           11       0.64      0.39      0.49       337
#           12       0.89      0.91      0.90       321
#           13       0.86      0.94      0.90       324
#           14       0.43      0.23      0.30       331
#           15       0.36      0.40      0.38       336
#           16       0.37      0.50      0.43       331
#           17       0.63      0.49      0.55       334
#           18       0.46      0.28      0.35       335
#           19       0.45      0.24      0.31       370
#           20       0.35      0.47      0.40       324
#
#     accuracy                           0.45      6600
#    macro avg       0.49      0.46      0.44      6600
# weighted avg       0.49      0.45      0.44      6600

# %%
import pandas as pd
confusion_matrix = list(metrics.confusion_matrix(y_test, predicted))

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = confusion_matrix
df_cm = pd.DataFrame(array, index = [i for i in names],
              columns = [i for i in names])
df_norm_col=(df_cm-df_cm.mean())/df_cm.std()
#df_norm_col=df_cm-df_cm.mean()
plt.figure(figsize = (10,7))
sn.heatmap(df_norm_col, annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>
