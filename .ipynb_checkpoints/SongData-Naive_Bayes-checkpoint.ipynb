# %%
import glob
import pandas as pd
import numpy as np
import requests
import os

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import time
import re
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import confusion_matrix
import joblib

# %%
all_file = glob.glob("../songData/*.xlsx")
all_file
# Out:
# ['../songData\\songType0.xlsx',
#  '../songData\\songType1.xlsx',
#  '../songData\\songType10.xlsx',
#  '../songData\\songType11.xlsx',
#  '../songData\\songType12.xlsx',
#  '../songData\\songType13.xlsx',
#  '../songData\\songType14.xlsx',
#  '../songData\\songType15.xlsx',
#  '../songData\\songType16.xlsx',
#  '../songData\\songType17.xlsx',
#  '../songData\\songType18.xlsx',
#  '../songData\\songType19.xlsx',
#  '../songData\\songType2.xlsx',
#  '../songData\\songType20.xlsx',
#  '../songData\\songType3.xlsx',
#  '../songData\\songType4.xlsx',
#  '../songData\\songType5.xlsx',
#  '../songData\\songType6.xlsx',
#  '../songData\\songType7.xlsx',
#  '../songData\\songType8.xlsx',
#  '../songData\\songType9.xlsx']

# %%
names = []
count = []
clusters = []
data = []

for each in all_file:    
    temp = pd.read_excel(each)
    
    count.append(len(temp))
    names.append(each.split('/')[1][:-5])
    clusters.append(temp['songType'])
    
    data.append(temp)
    cluster_ids = clusters

# %%
data = pd.concat(data)
data = data.sample(frac = 1)

data
# Out:
#      Unnamed: 0                                             lyrics  songType
# 226        1391  তুমি আসবে বলে হে প্রিয় নারী এ শহরের চাবি তোমা...        13
# 224        1636  আরো আঘাত সইবে আমার, সইবে আমারো।       আরো কঠিন...        17
# 331        1991  কি আশায় বাঁধি খেলাঘর বেদনার বালুচরে নিয়তি আম...         3
# 690        2876  দুঃখ আমাকে দুঃখী করেনি,করেছে রাজার রাজা ও রানী...         1
# 752        4049  সবাই কেন গাইতে গেলে প্রেমের গান’ই গায় ঘুরে ফি...         3
# ..          ...                                                ...       ...
# 440        2698  হায় হায় প্রেমে পড়লে। বার মাসই গান সবাই গান কোন...         3
# 41          119  তুমি আমার মনে রাজা আমি তোমার রানী, নাইবা তুমি ...         3
# 180        1564  মেঘের পরে মেঘ জমেছে, আঁধার করে আসে । আমায় কেন ...        17
# 55         3701  বাঁধা দিও না……না দিও না ও মোর প্রেম, ও মোর প্র...         9
# 629        2324  নিত্য তোমার যে ফুল ফোটে ফুলবনে তারি মধু কেন মন...        17
#
# [4105 rows x 3 columns]

# %%
stop_words = [ 'হাই', 'ফ্রিকুয়েন্সি', 'কিন্তু', 'অপ্রয়োজনীয়', 'শব্দ' ]

# %%
data['lyrics'] = data['lyrics'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
X_train, X_test, y_train, y_test = train_test_split(data['lyrics'], data['songType'], test_size=0.33, random_state=42)

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn import metrics

total_data_count = len(data)
per_class_counts = []
unique_classes = np.unique(data['songType'].values)
class_count_mean = np.mean(count)


from sklearn.naive_bayes import MultinomialNB
text_clf_svm = Pipeline([
    
    ('vect', CountVectorizer(stop_words=stop_words,
                            analyzer="word", 
                            lowercase=False,
                            token_pattern="[\S]*",
                            tokenizer=None,
                            ngram_range=(1, 3),
                            preprocessor=None)),                 
    ('tfidf', TfidfTransformer()),
    ('clf-svm', MultinomialNB()),
                                                                        
])
classifier = text_clf_svm.fit(list(X_train), list(y_train))


cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=0)
score = cross_val_score(text_clf_svm, list(X_train), list(y_train), cv=cv)

print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))


predicted = classifier.predict(X_test)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens [''] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# Cross Accuracy: 0.30 (+/- 0.01)

# %%
print("Cross Accuracy: %0.2f (+/- %0.2f)" % (score.mean(), score.std() * 2))
print(metrics.classification_report(y_test, predicted))
# Out:
# Cross Accuracy: 0.30 (+/- 0.01)
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.26      1.00      0.41       321
#            2       0.00      0.00      0.00         2
#            3       0.56      0.02      0.04       250
#            4       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00        17
#            6       0.00      0.00      0.00        28
#            7       0.00      0.00      0.00        67
#            8       0.00      0.00      0.00         7
#            9       0.00      0.00      0.00        17
#           10       0.00      0.00      0.00        14
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        40
#           13       0.00      0.00      0.00       252
#           14       0.00      0.00      0.00        10
#           15       0.00      0.00      0.00         1
#           16       0.00      0.00      0.00         2
#           17       0.95      0.37      0.53       286
#           18       0.00      0.00      0.00         3
#           19       0.00      0.00      0.00        13
#           20       0.00      0.00      0.00         2
#
#     accuracy                           0.32      1355
#    macro avg       0.08      0.07      0.05      1355
# weighted avg       0.36      0.32      0.22      1355
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
confusion_matrix = list(metrics.confusion_matrix(y_test, predicted))

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = confusion_matrix
df_cm = pd.DataFrame(array, index = [i for i in names],
              columns = [i for i in names])
df_norm_col=(df_cm-df_cm.mean())/df_cm.std()
#df_norm_col=df_cm-df_cm.mean()
plt.figure(figsize = (15,10))
sn.heatmap(df_norm_col, annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>
